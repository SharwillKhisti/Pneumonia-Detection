# %%
# Out:
# TRAIN -> NORMAL: 1342, PNEUMONIA: 3876
# VAL -> NORMAL: 9, PNEUMONIA: 9
# TEST -> NORMAL: 234, PNEUMONIA: 390
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[2], line 23
#      21 for i, img_name in enumerate(normal_imgs):
#      22     img_path = os.path.join(data_dir, "train", "NORMAL", img_name)
# ---> 23     img = mpimg.imread(img_path)
#      24     axes[0, i].imshow(img, cmap="gray")
#      25     axes[0, i].set_title("NORMAL")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\image.py:1512, in imread(fname, format)
#    1505 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1506     # Pillow doesn't handle URLs directly.
#    1507     raise ValueError(
#    1508         "Please open the URL for reading and pass the "
#    1509         "result to Pillow, e.g. with "
# ...
